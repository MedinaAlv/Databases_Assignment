# %%
# !pip install "prettytable<3.12"
# Out:
# 1739.46s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.18.0
#     Uninstalling prettytable-3.18.0:
#       Successfully uninstalled prettytable-3.18.0
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
# %load_ext sql

# %%
import os
from dotenv import load_dotenv

load_dotenv()

user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
database = os.getenv("DB_NAME")
# Out:
# root
# housing_poverty

# %%
# %sql mysql+pymysql://{user}:{password}@localhost/{database}

# %%
# %%sql
# SHOW TABLES;
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 9 rows affected.
# [('Application',),
#  ('City',),
#  ('Contract',),
#  ('Eligibility_Profile',),
#  ('House',),
#  ('Landlord',),
#  ('Municipality',),
#  ('Person',),
#  ('Tenant',)]

# %%
# %%sql
#
# CREATE TABLE Person (
#     person_id INT PRIMARY KEY,
#     first_name VARCHAR(50) NOT NULL,
#     last_name VARCHAR(50) NOT NULL,
#     email VARCHAR(50) UNIQUE NOT NULL,
#     phone_number VARCHAR(15) UNIQUE NOT NULL
# );
#
# CREATE TABLE Tenant (
#     person_id INT PRIMARY KEY REFERENCES Person(person_id),
#     date_of_birth DATE NOT NULL
# );
#
# CREATE TABLE Landlord (
#     person_id INT PRIMARY KEY REFERENCES Person(person_id)
# );
#
# CREATE TABLE Municipality (
#     municipality_id INT PRIMARY KEY,
#     municipality_name VARCHAR(50) NOT NULL,
#     municipality_level VARCHAR(50),
#     contact_email VARCHAR(50),
#     phone_number VARCHAR(15)
# );
#
# CREATE TABLE City (
#     city_id INT PRIMARY KEY,
#     municipality_id INT NOT NULL REFERENCES Municipality(municipality_id),
#     city_name VARCHAR(50) NOT NULL,
#     postal_code VARCHAR(20) NOT NULL
# );
#
# CREATE TABLE House (
#     house_id INT PRIMARY KEY,
#     landlord_id INT REFERENCES Landlord(person_id),
#     city_id INT REFERENCES City(city_id),
#     street VARCHAR(50) NOT NULL,
#     house_number INT NOT NULL,
#     monthly_rent INT NOT NULL,
#     number_of_rooms INT NOT NULL,
#     property_type VARCHAR(20),
#     availability_status VARCHAR(20) DEFAULT 'available'
# );
#
# CREATE TABLE Eligibility_Profile (
#     eligibility_id INT PRIMARY KEY,
#     tenant_id INT NOT NULL REFERENCES Tenant(person_id),
#     employment_status VARCHAR(50),
#     annual_income INT NOT NULL,
#     number_dependents INT DEFAULT 0,
#     max_affordable_rent INT,
#     assessment_date DATE NOT NULL DEFAULT (CURRENT_DATE)
# );
#
# CREATE TABLE Application (
#     application_id INT PRIMARY KEY,
#     tenant_id INT NOT NULL REFERENCES Tenant(person_id),
#     eligibility_id INT NOT NULL REFERENCES Eligibility_Profile(eligibility_id),
#     house_id INT NOT NULL REFERENCES House(house_id),
#     application_date DATE NOT NULL DEFAULT CURRENT_DATE,
#     application_status VARCHAR(50),
#     decision_date DATE
# );
#
# CREATE TABLE Contract (
#     contract_id INT PRIMARY KEY,
#     tenant_id INT NOT NULL REFERENCES Tenant(person_id),
#     house_id INT NOT NULL REFERENCES House(house_id),
#     start_date DATE NOT NULL,
#     end_date DATE,
#     minimum_contract_length INT,
#     monthly_rent INT NOT NULL CHECK (monthly_rent > 0),
#     contract_status VARCHAR(50) DEFAULT 'active'
# );
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# (pymysql.err.ProgrammingError) (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '--so we dont create duplicate tables, in case someone else runs it\nDROP TABLE IF' at line 1")
# [SQL: --so we dont create duplicate tables, in case someone else runs it
# DROP TABLE IF EXISTS Contract;]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# Task 4

# %%
# %%sql
#
# INSERT INTO Person
# (person_id, first_name, last_name, email, phone_number)
# VALUES
# (1, 'Anna', 'Müller', 'anna.mueller@example.com', '0612345678');
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 1 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM Person;
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 1 rows affected.
# [(1, 'Anna', 'Müller', 'anna.mueller@example.com', '0612345678')]

# %%
# %%sql
#
# SELECT first_name, last_name, email
# FROM Person;
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 1 rows affected.
# [('Anna', 'Müller', 'anna.mueller@example.com')]

# %%
# %%sql
#
# UPDATE Person
# SET phone_number = '0698765432'
# WHERE person_id = 1;
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 1 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM Person
# WHERE person_id = 1;
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 1 rows affected.
# [(1, 'Anna', 'Müller', 'anna.mueller@example.com', '0698765432')]

# %%
# %%sql
#
# DELETE FROM Person
# WHERE person_id = 1;
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 1 rows affected.
# []

# %%
# %%sql
#
# SELECT * FROM Person;
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 0 rows affected.
# []

# %% [markdown]
# Task 5 - Add Mock data

# %%
# %%sql
# INSERT INTO Person
# (person_id, first_name, last_name, email, phone_number)
# VALUES
# (1, 'Sophie', 'Jansen', 'sophie.jansen@example.com', '0611111111'),
# (2, 'Liam', 'de Vries', 'liam.devries@example.com', '0622222222'),
# (3, 'Emma', 'Bakker', 'emma.bakker@example.com', '0633333333'),
# (4, 'Noah', 'Smit', 'noah.smit@example.com', '0644444444'),
# (5, 'Julia', 'Visser', 'julia.visser@example.com', '0655555555'),
# (6, 'Lucas', 'Meijer', 'lucas.meijer@example.com', '0666666666'),
# (7, 'Anna', 'Mulder', 'anna.mulder@example.com', '0677777777'),
# (8, 'Mark', 'de Jong', 'mark.dejong@example.com', '0688888888'),
# (9, 'Thomas', 'Peters', 'thomas.peters@example.com', '0699999999'),
# (10, 'Lisa', 'van Dijk', 'lisa.vandijk@example.com', '0601010101'),
# (11, 'David', 'Smit', 'david.smit@example.com', '0602020202'),
# (12, 'Sarah', 'Visser', 'sarah.visser@example.com', '0603030303');
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 12 rows affected.
# []

# %%
# %%sql
# INSERT INTO Tenant
# (person_id, date_of_birth)
# VALUES
# (1, '2002-04-15'),
# (2, '1999-11-23'),
# (3, '2001-07-08'),
# (4, '2003-01-19'),
# (5, '2000-09-30'),
# (6, '1998-12-12'),
# (7, '2002-06-21');
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 7 rows affected.
# []

# %%
# %%sql
# INSERT INTO Landlord
# (person_id)
# VALUES
# (8),
# (9),
# (10),
# (11),
# (12);
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 5 rows affected.
# []

# %%
# %%sql
# INSERT INTO Municipality
# (municipality_id, municipality_name, municipality_level, contact_email, phone_number)
# VALUES
# (1, 'Meerssen', 'City', 'info@meerssen.example.com', '0228111111'),
# (2, 'Maastricht', 'City', 'info@maastricht.example.com', '0228222222'),
# (3, 'Groningen', 'City', 'info@groningen.example.com', '0241333333'),
# (4, 'Amsterdam', 'City', 'info@amsterdam.example.com', '0211444444');
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 4 rows affected.
# []

# %%
# %%sql
# INSERT INTO City
# (city_id, municipality_id, city_name, postal_code)
# VALUES
# (1, 1, 'Meerssen', '53111'),
# (2, 2, 'Maastricht', '50667'),
# (3, 3, 'Groningen', '52062'),
# (4, 4, 'Amsterdam', '40213');
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 4 rows affected.
# []

# %%
# %%sql
# INSERT INTO House
# (house_id, landlord_id, city_id, street, house_number, monthly_rent, number_of_rooms, property_type, availability_status)
# VALUES
# (1, 8, 1, 'Kuileneindestraat', 10, 550, 2, 'Apartment', 'available'),
# (2, 8, 1, 'Bunderstraat', 25, 720, 3, 'Apartment', 'rented'),
# (3, 9, 2, 'Wycker Brugstraat', 45, 680, 2, 'Apartment', 'available'),
# (4, 9, 2, 'Tongerseweg', 18, 850, 3, 'Apartment', 'available'),
# (5, 10, 3, 'Oosterhamrikkade', 12, 500, 1, 'Studio', 'available'),
# (6, 10, 3, 'Helper Brink', 33, 650, 2, 'Apartment', 'rented'),
# (7, 11, 4, 'Jan Evertsenstraat', 8, 780, 3, 'Apartment', 'available'),
# (8, 11, 4, 'Kinkerstraat', 40, 1200, 4, 'Apartment', 'rented'),
# (9, 12, 1, 'Pastoor N. Creemersstraat', 55, 600, 2, 'Apartment', 'available'),
# (10, 12, 2, 'Brusselsestraat', 100, 950, 3, 'House', 'available');
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 10 rows affected.
# []

# %%
# %%sql
# INSERT INTO Eligibility_Profile
# (eligibility_id, tenant_id, employment_status, annual_income, number_dependents, max_affordable_rent, assessment_date)
# VALUES
# (1, 1, 'Student', 18000, 0, 600, '2026-09-01'),
# (2, 2, 'Part-time employed', 24000, 0, 700, '2026-09-02'),
# (3, 3, 'Student', 15000, 0, 550, '2026-09-03'),
# (4, 4, 'Student', 12000, 0, 500, '2026-09-04'),
# (5, 5, 'Full-time employed', 32000, 1, 800, '2026-09-05'),
# (6, 6, 'Full-time employed', 38000, 2, 900, '2026-09-06'),
# (7, 7, 'Student', 17000, 0, 600, '2026-09-07');
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 7 rows affected.
# []

# %%
# %%sql
# INSERT INTO Application
# (application_id, tenant_id, eligibility_id, house_id, application_date, application_status, decision_date)
# VALUES
# (1, 1, 1, 1, '2026-09-02', 'approved', '2026-09-05'),
# (2, 2, 2, 3, '2026-09-03', 'pending', NULL),
# (3, 3, 3, 5, '2026-09-04', 'approved', '2026-09-06'),
# (4, 4, 4, 1, '2026-09-05', 'rejected', '2026-09-08'),
# (5, 5, 5, 7, '2026-09-06', 'pending', NULL),
# (6, 6, 6, 10, '2026-09-07', 'approved', '2026-09-10'),
# (7, 7, 7, 9, '2026-09-08', 'pending', NULL);

# %%
# %%sql
# INSERT INTO Contract
# (contract_id, tenant_id, house_id, start_date, end_date, minimum_contract_length, monthly_rent, contract_status)
# VALUES
# (1, 1, 1, '2026-10-01', '2027-09-30', 12, 550, 'active'),
# (2, 3, 5, '2026-10-01', '2027-09-30', 12, 500, 'active'),
# (3, 6, 10, '2026-10-15', NULL, 12, 950, 'active'),
# (4, 2, 2, '2025-09-01', '2026-08-31', 12, 720, 'expired'),
# (5, 5, 7, '2026-01-01', '2026-12-31', 12, 780, 'active');
# Out:
#  * mysql+pymysql://root:***@localhost/housing_poverty
# 5 rows affected.
# []

# %% [markdown]
# ## Task 6 - Advanced Queries
#
# The following queries use joins, calculations, grouping, and aggregate functions to analyse housing affordability.

# %% [markdown]
# ### Query 1: Match tenants with affordable available houses
#
# This query returns every available property within each tenant's maximum affordable rent and calculates how much of their monthly housing budget would remain.

# %%
# %%sql
# SELECT
#     ep.tenant_id,
#     CONCAT(p.first_name, ' ', p.last_name) AS tenant_name,
#     ep.employment_status,
#     ep.max_affordable_rent,
#     h.house_id,
#     c.city_name,
#     CONCAT(h.street, ' ', h.house_number) AS property_address,
#     h.monthly_rent,
#     ep.max_affordable_rent - h.monthly_rent AS remaining_rent_budget
# FROM Eligibility_Profile AS ep
# JOIN Person AS p
#     ON p.person_id = ep.tenant_id
# JOIN House AS h
#     ON h.availability_status = 'available'
#    AND h.monthly_rent <= ep.max_affordable_rent
# JOIN City AS c
#     ON c.city_id = h.city_id
# ORDER BY tenant_name, h.monthly_rent;
# Out:
#  * mysql+pymysql://housing_app:***@localhost/housing_poverty
# 24 rows affected.
# [(7, 'Anna Mulder', 'Student', 600, 5, 'Groningen', 'Oosterhamrikkade 12', 500, 100),
#  (7, 'Anna Mulder', 'Student', 600, 1, 'Meerssen', 'Kuileneindestraat 10', 550, 50),
#  (7, 'Anna Mulder', 'Student', 600, 9, 'Meerssen', 'Pastoor N. Creemersstraat 55', 600, 0),
#  (3, 'Emma Bakker', 'Student', 550, 5, 'Groningen', 'Oosterhamrikkade 12', 500, 50),
#  (3, 'Emma Bakker', 'Student', 550, 1, 'Meerssen', 'Kuileneindestraat 10', 550, 0),
#  (5, 'Julia Visser', 'Full-time employed', 800, 5, 'Groningen', 'Oosterhamrikkade 12', 500, 300),
#  (5, 'Julia Visser', 'Full-time employed', 800, 1, 'Meerssen', 'Kuileneindestraat 10', 550, 250),
#  (5, 'Julia Visser', 'Full-time employed', 800, 9, 'Meerssen', 'Pastoor N. Creemersstraat 55', 600, 200),
#  (5, 'Julia Visser', 'Full-time employed', 800, 3, 'Maastricht', 'Wycker Brugstraat 45', 680, 120),
# ...

# %% [markdown]
# ### Query 2: Compare rental markets by city
#
# This query summarises the number of properties, availability, and advertised rents in each city.

# %%
# %%sql
# SELECT
#     c.city_id,
#     c.city_name,
#     COUNT(h.house_id) AS total_properties,
#     SUM(CASE WHEN h.availability_status = 'available' THEN 1 ELSE 0 END) AS available_properties,
#     ROUND(AVG(h.monthly_rent), 2) AS average_monthly_rent,
#     MIN(h.monthly_rent) AS minimum_monthly_rent,
#     MAX(h.monthly_rent) AS maximum_monthly_rent
# FROM City AS c
# LEFT JOIN House AS h
#     ON h.city_id = c.city_id
# GROUP BY c.city_id, c.city_name
# ORDER BY average_monthly_rent;
# Out:
#  * mysql+pymysql://housing_app:***@localhost/housing_poverty
# 4 rows affected.
# [(3, 'Groningen', 2, Decimal('1'), Decimal('575.00'), 500, 650),
#  (1, 'Meerssen', 3, Decimal('2'), Decimal('623.33'), 550, 720),
#  (2, 'Maastricht', 3, Decimal('3'), Decimal('826.67'), 680, 950),
#  (4, 'Amsterdam', 2, Decimal('1'), Decimal('990.00'), 780, 1200)]

# %% [markdown]
# ### Query 3: Summarise affordable choices by tenant and city
#
# This query combines the first two ideas by counting and summarising the affordable available properties each tenant has in each city.

# %%
# %%sql
# SELECT
#     ep.tenant_id,
#     CONCAT(p.first_name, ' ', p.last_name) AS tenant_name,
#     ep.max_affordable_rent,
#     c.city_name,
#     COUNT(h.house_id) AS affordable_properties,
#     MIN(h.monthly_rent) AS cheapest_affordable_rent,
#     ROUND(AVG(h.monthly_rent), 2) AS average_affordable_rent
# FROM Eligibility_Profile AS ep
# JOIN Person AS p
#     ON p.person_id = ep.tenant_id
# JOIN House AS h
#     ON h.availability_status = 'available'
#    AND h.monthly_rent <= ep.max_affordable_rent
# JOIN City AS c
#     ON c.city_id = h.city_id
# GROUP BY
#     ep.tenant_id, p.first_name, p.last_name,
#     ep.max_affordable_rent, c.city_id, c.city_name
# HAVING COUNT(h.house_id) > 0
# ORDER BY tenant_name, affordable_properties DESC, average_affordable_rent;
# Out:
#  * mysql+pymysql://housing_app:***@localhost/housing_poverty
# 18 rows affected.
# [(7, 'Anna Mulder', 600, 'Meerssen', 2, 550, Decimal('575.00')),
#  (7, 'Anna Mulder', 600, 'Groningen', 1, 500, Decimal('500.00')),
#  (3, 'Emma Bakker', 550, 'Groningen', 1, 500, Decimal('500.00')),
#  (3, 'Emma Bakker', 550, 'Meerssen', 1, 550, Decimal('550.00')),
#  (5, 'Julia Visser', 800, 'Meerssen', 2, 550, Decimal('575.00')),
#  (5, 'Julia Visser', 800, 'Groningen', 1, 500, Decimal('500.00')),
#  (5, 'Julia Visser', 800, 'Maastricht', 1, 680, Decimal('680.00')),
#  (5, 'Julia Visser', 800, 'Amsterdam', 1, 780, Decimal('780.00')),
#  (2, 'Liam de Vries', 700, 'Meerssen', 2, 550, Decimal('575.00')),
#  (2, 'Liam de Vries', 700, 'Groningen', 1, 500, Decimal('500.00')),
#  (2, 'Liam de Vries', 700, 'Maastricht', 1, 680, Decimal('680.00')),
#  (6, 'Lucas Meijer', 900, 'Meerssen', 2, 550, Decimal('575.00')),
#  (6, 'Lucas Meijer', 900, 'Maastricht', 2, 680, Decimal('765.00')),
# ...
